# %%
import KTreeModel

tree = KTreeModel.KTree()

# en iyi k ve d değerlerini için yarat
tree.create_tree(6,3)

tree.photo_test()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 8
#       4
#       5 # en iyi k ve d değerlerini için yarat
#       6 tree.create_tree(6,3)
#       7
# ----> 8 tree.photo_test()
#
# File c:\DEV\Bil468_HW3\KTreeModel.py:267, in KTree.photo_test(self)
#     265 patch = image[y:y + window, x:x + window]
#     266 _, feats = sift.detectAndCompute(patch,None)
# --> 267 class_val = self.find_class_value(feats)
#     268 mask = class_val == 0
#     269 class_val[mask] = -1
#
# File c:\DEV\Bil468_HW3\KTreeModel.py:154, in KTree.find_class_value(self, X)
#     151 model = self.k_means_models[level][node_index]
#     153 if isinstance(model, KMeans):
# --> 154     predictions = model.predict(X[sample_indices])
#     156     node_indices[sample_indices] = (
#     157         node_index * self.k + predictions
#     158     )
#     159 else:
#
# ...
