# %%
import KTreeModel

tree = KTreeModel.KTree()

# %%
import pandas as pd
import math
import time 

csv_file = "results.csv"
df = pd.DataFrame(columns=["k","d","time","accuracy", "precision", "recall", "f1","confusion"])
df.to_csv(csv_file, index=False)

try:
    for k in range(2,41):
        data_count = len(tree.train_x)
        dmax = int(math.log(data_count, k))
        for d in range(2, dmax+1):
            start = time.time()
            tree.create_tree(k,d)
            accuracy, precision, recall, f1, cm = tree.validate_features()
            elapsed = time.time() - start
            df = pd.read_csv(csv_file)
            df.loc[len(df)] = [k, d, elapsed, accuracy, precision, recall, f1, cm]
            df.to_csv(csv_file,index=False)

            if elapsed > 300: # 5 dk max
                break
except Exception as e:
    import os
    #os.system("shutdown /s /t 0")
# Out:
# c:\Users\alibe\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\alibe\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\alibe\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
import pandas as pd
import KTreeModel

best_k = 29
best_d = 4
tree = KTreeModel.KTree()
tree.create_tree(best_k,best_d)
tree.test()
# Out:
#   7%|▋         | 41799/596400 [03:53<51:36, 179.10it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       4 best_k = 29
#       5 best_d = 4
#       6 tree = KTreeModel.KTree()
#       7 tree.create_tree(best_k,best_d)
# ----> 8 tree.test()
#
# File c:\DEV\Bil468_HW3\KTreeModel.py:231, in KTree.test(self)
#     227 label_true = self.test_frames[i][1]
#     229 y_true.append(label_true)
# --> 231 win_predict = self.find_class_value(features)
#     232 mask = win_predict == 0
#     233 win_predict[mask] = -1
#
# File c:\DEV\Bil468_HW3\KTreeModel.py:157, in KTree.find_class_value(self, X)
#     154 model = self.k_means_models[level][node_index]
#     156 if isinstance(model, KMeans):
# --> 157     predictions = model.predict(X[sample_indices])
#     159     node_indices[sample_indices] = (
#     160         node_index * self.k + predictions
#     161     )
#     162 else:
#
# File c:\Users\alibe\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\cluster\_kmeans.py:1099, in _BaseKMeans.predict(self, X)
#    1096 # sample weights are not used by predict but cython helpers expect an array
#    1097 sample_weight = np.ones(X.shape[0], dtype=X.dtype)
# -> 1099 labels = _labels_inertia_threadpool_limit(
#    1100     X,
#    1101     sample_weight,
#    1102     self.cluster_centers_,
#    1103     n_threads=self._n_threads,
#    1104     return_inertia=False,
#    1105 )
#    1107 return labels
#
# File c:\Users\alibe\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py:210, in _threadpool_controller_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 controller = _get_threadpool_controller()
#     209 with controller.limit(limits=limits, user_api=user_api):
# --> 210     return func(*args, **kwargs)
#
# File c:\Users\alibe\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\cluster\_kmeans.py:812, in _labels_inertia(X, sample_weight, centers, n_threads, return_inertia)
#     809     _labels = lloyd_iter_chunked_dense
#     810     _inertia = _inertia_dense
# --> 812 _labels(
#     813     X,
#     814     sample_weight,
#     815     centers,
#     816     centers_new=None,
#     817     weight_in_clusters=None,
#     818     labels=labels,
#     819     center_shift=center_shift,
#     820     n_threads=n_threads,
#     821     update_centers=False,
#     822 )
#     824 if return_inertia:
#     825     inertia = _inertia(X, sample_weight, centers, labels, n_threads)
#
# KeyboardInterrupt:
