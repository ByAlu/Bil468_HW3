# %%
import KTreeModel

tree = KTreeModel.KTree()

# %%
models, clusters, time = tree.create_tree(3,3)

# %%
tree.find_class_value(tree.train_x[0], models, clusters)
# Out:
# [     0      6     49 ... 966197 966260 966263]
